# %%
#importing the dataset
import pandas as pd   #importing pandas
data=pd.read_csv(r"C:\Users\RAKSHIT GROVER\Desktop\8. Netflix Dataset (3).csv")

# %%
data
# Out:
#      Unnamed: 0 Category                                    Title  \
# 0            s1  TV Show                                       3%
# 1            s2    Movie                                    07:19
# 2            s3    Movie                                    23:59
# 3            s4    Movie                                        9
# 4            s5    Movie                                       21
# ...         ...      ...                                      ...
# 7784      s7783    Movie                                     Zozo
# 7785      s7784    Movie                                   Zubaan
# 7786      s7785    Movie                        Zulu Man in Japan
# 7787      s7786  TV Show                    Zumbo's Just Desserts
# 7788      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # GETTING SOME BASIC INFORMATION ABOUT THE DATASET

# %% [markdown]
# # 1.head()

# %%
data.head()                    #to show top5 records of the dataset
# Out:
#   Unnamed: 0 Category  Title           Director  \
# 0         s1  TV Show     3%                NaN
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
# 3         s4    Movie      9        Shane Acker
# 4         s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # 2. tail()

# %%
data.tail()                          #to show bottom 5 records of dataset
# Out:
#      Unnamed: 0 Category                                    Title  \
# 7784      s7783    Movie                                     Zozo
# 7785      s7784    Movie                                   Zubaan
# 7786      s7785    Movie                        Zulu Man in Japan
# 7787      s7786  TV Show                    Zumbo's Just Desserts
# 7788      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#          Director                                               Cast  \
# 7784  Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786          NaN                                            Nasty C
# 7787          NaN                         Adriano Zumbo, Rachel Khoo
# 7788     Sam Dunn                                                NaN
#
#                                                 Country        Release_Date  \
# ...

# %% [markdown]
# ## 3.shape

# %%
data.shape                                            # to show the no. of rows and columns
# Out:
# (7789, 11)

# %% [markdown]
# # 4. size

# %%
data.size                                 #to show no. of total values(elements) in the dataset
# Out:
# 85679

# %% [markdown]
# # 5.columns

# %%
data.columns                                      #to show each column name
# Out:
# Index(['Unnamed: 0', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # 6.data types

# %%
data.dtypes                   #to show the data types of each column
# Out:
# Unnamed: 0      object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# # 7.info()

# %%
data.info()                      #to show indexes,columns,data-types of each column ,memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # TASK 1. -IS THERE ANY DUPLICATE RECORD IN THE DATASET?IF YES,THEN REMOVE THE DUPLICATE RECORDS

# %% [markdown]
# ## DUPLICATE()

# %%
data.head()
# Out:
#   Unnamed: 0 Category  Title           Director  \
# 0         s1  TV Show     3%                NaN
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
# 3         s4    Movie      9        Shane Acker
# 4         s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]                                 #to check row wise and detect duplicate rows
# Out:
#      Unnamed: 0 Category              Title        Director  \
# 6300       s684    Movie           Backfire     Dave Patten
# 6622      s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace= True)                            # to remove the duplicate rows permanently

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ## TASK2- TO FIND IF THERE ARE ANY NULL VALUES PRESENT IN ANY COLUMN AND ALSO SHOWING THE HEAT MAP

# %% [markdown]
# ### isnull()

# %%
data.isnull()                                       #to find out where null values are present
# Out:
#       Unnamed: 0  Category  Title  Director   Cast  Country  Release_Date  \
# 0          False     False  False      True  False    False         False
# 1          False     False  False     False  False    False         False
# 2          False     False  False     False  False    False         False
# 3          False     False  False     False  False    False         False
# 4          False     False  False     False  False    False         False
# ...          ...       ...    ...       ...    ...      ...           ...
# 7784       False     False  False     False  False    False         False
# 7785       False     False  False     False  False    False         False
# 7786       False     False  False      True  False     True         False
# 7787       False     False  False      True  False    False         False
# 7788       False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# ...

# %%
data.isnull().sum()                                     #to show the count of null values in each column
# Out:
# Unnamed: 0         0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ## seaborn library (heat map)

# %%
import seaborn as sns                       #to import seaborn library

# %%
sns.heatmap(data.isnull())                          #using heat map to show null values count
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##  Q.1.FOR 'HOUSE OF CARDS' ,WHAT IS THE SHOW ID AND WHO IS THE DIRECTOR OF THIS SHOW?

# %% [markdown]
# ### isin()

# %%
data[data['Title'].isin(['House of Cards'])]              #to show the records of a particular item in any column
# Out:
#      Unnamed: 0 Category           Title  \
# 2832      s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ###  another method

# %% [markdown]
# ## str.contains()

# %%
data [data['Title'].str.contains('House of Cards')]                   #to show the records of a particular item in any column
# Out:
#      Unnamed: 0 Category           Title  \
# 2832      s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## Q.2. IN WHICH YEAR THE HIGHEST NUMBER OF TV SHOWS AND MOVIES WERE RELEASED ?SHOW WITH BAR GRAPH

# %%
data.dtypes
# Out:
# Unnamed: 0      object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()                           #to show new column has been created
# Out:
#   Unnamed: 0 Category  Title           Director  \
# 0         s1  TV Show     3%                NaN
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
# 3         s4    Movie      9        Shane Acker
# 4         s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ### dt.year.value_counts()-It counts the occurence of all individual years in date column

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %% [markdown]
# ### BAR GRAPH

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Q.3. TO COUNT THE NUMBER OF TV SHOWS AND MOVIES IN THE DATASET ? SHOW WITH BAR GRAPH

# %%
data.head(1)
# Out:
#   Unnamed: 0 Category Title Director  \
# 0         s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14

# %% [markdown]
# ### groupby()-to group all unique items of a column and show their count

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# ### countplot()- to show the count of all unique values of any column in the form of bar graph

# %%
sns.countplot(data['Category'])
# Out:
# C:\Users\RAKSHIT GROVER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## Q.4. TO SHOW ALL THE MOVIES THAT WERE RELEASED IN YEAR 2020.

# %%
data['Year']=data['Date_N'].dt.year                        #to create new column Year

# %%
data.head(3)                                                  #to show new column has been created
# Out:
#   Unnamed: 0 Category  Title           Director  \
# 0         s1  TV Show     3%                NaN
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %% [markdown]
# ## filtering the data to find the answer

# %%
data[(data['Category']== 'Movie') &(data['Year']==2020)]
# Out:
#      Unnamed: 0 Category                                    Title  \
# 4            s5    Movie                                       21
# 6            s7    Movie                                      122
# 14          s15    Movie                                     3022
# 27          s28    Movie                                   #Alive
# 28          s29    Movie            #AnneFrank - Parallel Stories
# ...         ...      ...                                      ...
# 7762      s7761    Movie                                Zaki Chan
# 7783      s7782    Movie                                     Zoom
# 7784      s7783    Movie                                     Zozo
# 7786      s7785    Movie                        Zulu Man in Japan
# 7788      s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# ...

# %% [markdown]
# ## Q.5. TO SHOW ALL THE TITLES OF THE MOVIES RELEASED IN UNITED STATES ONLY.

# %%
data [(data['Category']== 'Movie') & (data['Country']=='United States')]['Title']
# Out:
# 3                                9
# 4                               21
# 7                              187
# 10                            1922
# 14                            3022
#                    ...
# 7760    Zack and Miri Make a Porno
# 7773                          Zion
# 7776                        Zodiac
# 7780                    Zombieland
# 7783                          Zoom
# Name: Title, Length: 1850, dtype: object

# %% [markdown]
# ## Q.6. To show the top 15 directors ,who gave highest number of TV shows and Movies to Netflix?

# %%
data['Director'].value_counts().head(15)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Robert Rodriguez           8
# Quentin Tarantino          8
# Shannon Hartman            8
# Ryan Polito                8
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ## Q.7. SHOW ALL THE RECORDS ,WHERE CATEGORY IS MOVIE AND TYPE IS DRAMAS OR COUNTRY IS ITALY?

# %%
data[(data['Category']== 'Movie')& (data['Type']=='Dramas')|(data['Country']=='Italy')]
# Out:
#      Unnamed: 0 Category                          Title  \
# 4            s5    Movie                             21
# 7            s8    Movie                            187
# 28          s29    Movie  #AnneFrank - Parallel Stories
# 73          s74    Movie                    18 Presents
# 111        s112  TV Show                        44 Cats
# ...         ...      ...                            ...
# 7449      s7448    Movie                            VS.
# 7465      s7464    Movie                      Wakefield
# 7480      s7479    Movie                      War Horse
# 7527      s7526    Movie          Welcome Mr. President
# 7641      s7640  TV Show                      Winx Club
#
#                          Director  \
# 4                  Robert Luketic
# 7                  Kevin Reynolds
# 28    Sabina Fedeli, Anna Migotto
# 73                Francesco Amato
# 111                           NaN
# ...                           ...
# 7449                     Ed Lilly
# ...

# %% [markdown]
# ## Q.8. TO FIND OUT NUMBER OF MOVIES IN WHICH KEVIN REYNOLDS WAS DIRECTOR.

# %%
data_new = data.dropna()

# %%
data_new.head(3)
# Out:
#   Unnamed: 0 Category  Title           Director  \
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
# 3         s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description     Date_N    Year
# ...

# %%
data_new[data_new['Director'].str.contains('Kevin Reynolds')]
# Out:
#   Unnamed: 0 Category Title        Director  \
# 7         s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#        Release_Date Rating Duration    Type  \
# 7  November 1, 2019      R  119 min  Dramas
#
#                                          Description     Date_N    Year
# 7  After one of his high school students attacks ... 2019-11-01  2019.0

# %% [markdown]
# ## Q.9.WHAT ARE DIFFERENT RATINNGS DEFINED BY NETFLIX?

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## Q.9.A) HOW MANY MOVIES GOT THE 'TV-PG' RATING IN CANADA?

# %%
data[(data['Category']=='Movie') & (data['Rating']== 'TV-PG' ) & (data['Country']=='Canada')]
# Out:
#      Unnamed: 0 Category                                              Title  \
# 101        s102    Movie                                  3 Seconds Divorce
# 1119      s1120    Movie               Bruno and Boots: Go Jump in the Pool
# 1120      s1121    Movie                    Bruno and Boots: The Wizzle War
# 1121      s1122    Movie  Bruno and Boots: This Can't Be Happening at Ma...
# 1248      s1249    Movie           Catwalk: Tales from the Cat Show Circuit
# 1370      s1371    Movie                            Christmas with a Prince
# 1371      s1372    Movie                              Christmas With A View
# 1665      s1666    Movie                                         Dear Santa
# 2552      s2553    Movie                                        Gun Runners
# 3044      s3045    Movie               Invisible Essence: The Little Prince
# 4013      s4014    Movie                                    Meditation Park
# ...

# %% [markdown]
# ## Q.9.B) HOW MANY TV SHOWS GOT THE 'R' RATING ,AFTER YEAR 2018?

# %%
data[(data['Category']=='TV Show') &  (data['Rating']=='R') & (data['Year'] > 2018)]
# Out:
#      Unnamed: 0 Category                                Title  \
# 6437      s6436  TV Show  The Hateful Eight: Extended Version
#
#                Director                                               Cast  \
# 6437  Quentin Tarantino  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...
#
#      Country    Release_Date Rating  Duration      Type  \
# 6437     NaN  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ## Q.10 WHAT IS THE MAXIMUM DURATION OF A MOVIE/SHOW ON NETFLIX?

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data[['Minutes','Unit'] ] = data['Duration'].str.split(' ',expand=True)

# %%
data.head(4)
# Out:
#   Unnamed: 0 Category  Title           Director  \
# 0         s1  TV Show     3%                NaN
# 1         s2    Movie  07:19  Jorge Michel Grau
# 2         s3    Movie  23:59       Gilbert Chan
# 3         s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
data.Minutes.max()
# Out:
# '99'

# %% [markdown]
# ## Q.11. WHICH INDIVIDUAL COUNTRY HAS THE HIGHEST NO. OF TV SHOWS?

# %%
data_tvshow=data[data['Category']== 'TV Show']

# %%
data_tvshow.head(4)
# Out:
#    Unnamed: 0 Category Title              Director  \
# 0          s1  TV Show    3%                   NaN
# 5          s6  TV Show    46           Serdar Akar
# 11        s12  TV Show  1983                   NaN
# 12        s13  TV Show  1994  Diego Enrique Osorno
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
#
#          Release_Date Rating   Duration  \
# 0     August 14, 2020  TV-MA  4 Seasons
# 5        July 1, 2017  TV-MA   1 Season
# 11  November 30, 2018  TV-MA   1 Season
# 12       May 17, 2019  TV-MA   1 Season
#
#                                                  Type  \
# 0   International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# United States                                                  705
# United Kingdom                                                 204
# Japan                                                          157
# South Korea                                                    147
# India                                                           71
#                                                               ...
# Canada, United States, Ireland                                   1
# Chile, Italy                                                     1
# Argentina, United States, Mexico                                 1
# United States, France, Canada                                    1
# Italy, South Africa, West Germany, Australia, United States      1
# Name: Country, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ## HOW CAN WE SORT THE DATASET BY EAR ?

# %%
data.sort_values(by='Year')
# Out:
#      Unnamed: 0 Category                         Title              Director  \
# 7115      s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765      s1766  TV Show               Dinner for Five                   NaN
# 3248      s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766      s5766    Movie                      Splatter             Joe Dante
# 3840      s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...         ...      ...                           ...                   ...
# 3374      s3375  TV Show                      Kikoriki                   NaN
# 3492      s3493  TV Show           La Familia P. Luche                   NaN
# 3946      s3947  TV Show                         Maron                   NaN
# 5138      s5138  TV Show                  Red vs. Blue                   NaN
# 6066      s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
# ...

# %%
data.sort_values(by='Year',ascending=False)
# Out:
#      Unnamed: 0 Category                         Title  \
# 5564      s5564    Movie               Sherlock Holmes
# 5919      s5919    Movie                     Surf's Up
# 980        s981  TV Show                  Bling Empire
# 5955      s5955    Movie              Taare Zameen Par
# 366        s367    Movie                     Al acecho
# ...         ...      ...                           ...
# 3374      s3375  TV Show                      Kikoriki
# 3492      s3493  TV Show           La Familia P. Luche
# 3946      s3947  TV Show                         Maron
# 5138      s5138  TV Show                  Red vs. Blue
# 6066      s6066  TV Show  The Adventures of Figaro Pho
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 5955               Aamir Khan
# 366       Francisco D'Eufemia
# ...                       ...
# 3374                      NaN
# 3492                      NaN
# ...

# %% [markdown]
# ## Q.13. TO FIND ALL THE INSTANCES IN WHICH CATEGORY IS MOVIES AND TYPE IS THRILLER OR CATEGORY IS TV SHOW AND TYPE IS TV COMEDIES.

# %%
data[(data['Category']=='Movie') & (data['Type']== 'Thriller') | (data['Category']=='TV Show') & (data['Type']=='TV Comedies')
]
# Out:
#      Unnamed: 0 Category                                     Title Director  \
# 29          s30  TV Show                                  #blackAF      NaN
# 306        s307  TV Show                     Adam Ruins Everything      NaN
# 404        s405  TV Show                 All About the Washingtons      NaN
# 583        s584  TV Show                      Arrested Development      NaN
# 603        s604  TV Show           Astronomy Club: The Sketch Show      NaN
# ...         ...      ...                                       ...      ...
# 7320      s7319  TV Show                 Unbreakable Kimmy Schmidt      NaN
# 7452      s7451  TV Show                            W/ Bob & David      NaN
# 7544      s7543  TV Show                   Wet Hot American Summer      NaN
# 7545      s7544  TV Show  Wet Hot American Summer: Ten Years Later      NaN
# 7737      s7736  TV Show                            Young & Hungry      NaN
#
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']== 'Thriller') | (data['Category']=='TV Show') & (data['Type']=='TV Comedies')
].head()
# Out:
#     Unnamed: 0 Category                            Title Director  \
# 29         s30  TV Show                         #blackAF      NaN
# 306       s307  TV Show            Adam Ruins Everything      NaN
# 404       s405  TV Show        All About the Washingtons      NaN
# 583       s584  TV Show             Arrested Development      NaN
# 603       s604  TV Show  Astronomy Club: The Sketch Show      NaN
#
#                                                   Cast        Country  \
# 29   Kenya Barris, Rashida Jones, Iman Benson, Genn...  United States
# 306           Adam Conover, Adam Lustick, Emily Axford  United States
# 404  Joseph Simmons, Justine Simmons, Kiana Ledé, N...  United States
# 583  Jason Bateman, Portia de Rossi, Will Arnett, M...  United States
# 603  Shawtane Bowen, Jonathan Braylock, Ray Cordova...  United States
#
#            Release_Date Rating   Duration         Type  \
# 29       April 17, 2020  TV-MA   1 Season  TV Comedies
# ...
